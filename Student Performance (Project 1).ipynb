# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("student_performance.csv")

# %%
print(df)
# Out:
#     Student_ID  Gender  Age  Study_Hours  Attendance  Marks Department
# 0         1001    Male   19            3          78     68         CS
# 1         1002  Female   20            5          92     84         IT
# 2         1003    Male   19            2          65     55         CS
# 3         1004  Female   21            6          95     91         IT
# 4         1005    Male   20            4          84     73         CS
# 5         1006  Female   19            7          97     95         IT
# 6         1007    Male   22            3          73     64         CS
# 7         1008  Female   20            5          89     82         IT
# 8         1009    Male   21            2          61     51         CS
# 9         1010  Female   19            8          98     97         IT
# 10        1011    Male   20            4          80     70         CS
# 11        1012  Female   21            6          91     88         IT
# ...

# %%
df.shape
# Out:
# (20, 7)

# %%
df.columns
# Out:
# Index(['Student_ID', 'Gender', 'Age', 'Study_Hours', 'Attendance', 'Marks',
#        'Department'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Student_ID      int64
# Gender         object
# Age             int64
# Study_Hours     int64
# Attendance      int64
# Marks           int64
# Department     object
# dtype: object

# %%
df.isnull()
# Out:
#     Student_ID  Gender    Age  Study_Hours  Attendance  Marks  Department
# 0        False   False  False        False       False  False       False
# 1        False   False  False        False       False  False       False
# 2        False   False  False        False       False  False       False
# 3        False   False  False        False       False  False       False
# 4        False   False  False        False       False  False       False
# 5        False   False  False        False       False  False       False
# 6        False   False  False        False       False  False       False
# 7        False   False  False        False       False  False       False
# 8        False   False  False        False       False  False       False
# 9        False   False  False        False       False  False       False
# 10       False   False  False        False       False  False       False
# 11       False   False  False        False       False  False       False
# ...

# %%
df.describe()
# Out:
#        Student_ID        Age  Study_Hours  Attendance      Marks
# count    20.00000  20.000000    20.000000   20.000000  20.000000
# mean   1010.50000  20.150000     4.500000   83.200000  75.800000
# std       5.91608   1.089423     1.791794   11.311848  14.299798
# min    1001.00000  19.000000     2.000000   61.000000  51.000000
# 25%    1005.75000  19.000000     3.000000   75.250000  63.500000
# 50%    1010.50000  20.000000     4.500000   85.000000  77.000000
# 75%    1015.25000  21.000000     6.000000   92.500000  88.500000
# max    1020.00000  22.000000     8.000000   98.000000  97.000000

# %%
df["Study_Hours"].mean()
# Out:
# np.float64(4.5)

# %%
df["Marks"].mean()
# Out:
# np.float64(75.8)

# %%
df["Marks"].max()
# Out:
# 97

# %%
df
# Out:
#     Student_ID  Gender  Age  Study_Hours  Attendance  Marks Department
# 0         1001    Male   19            3          78     68         CS
# 1         1002  Female   20            5          92     84         IT
# 2         1003    Male   19            2          65     55         CS
# 3         1004  Female   21            6          95     91         IT
# 4         1005    Male   20            4          84     73         CS
# 5         1006  Female   19            7          97     95         IT
# 6         1007    Male   22            3          73     64         CS
# 7         1008  Female   20            5          89     82         IT
# 8         1009    Male   21            2          61     51         CS
# 9         1010  Female   19            8          98     97         IT
# 10        1011    Male   20            4          80     70         CS
# 11        1012  Female   21            6          91     88         IT
# ...

# %%
df["Marks"] == 97
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# Name: Marks, dtype: bool

# %%
df.loc[9]
# Out:
# Student_ID       1010
# Gender         Female
# Age                19
# Study_Hours         8
# Attendance         98
# Marks              97
# Department         IT
# Name: 9, dtype: object

# %%
df["Department"].value_counts()
# Out:
# Department
# CS    10
# IT    10
# Name: count, dtype: int64

# %%
cs = (df["Department"] == "CS")
df[cs]
# Out:
#     Student_ID Gender  Age  Study_Hours  Attendance  Marks Department
# 0         1001   Male   19            3          78     68         CS
# 2         1003   Male   19            2          65     55         CS
# 4         1005   Male   20            4          84     73         CS
# 6         1007   Male   22            3          73     64         CS
# 8         1009   Male   21            2          61     51         CS
# 10        1011   Male   20            4          80     70         CS
# 12        1013   Male   19            3          76     62         CS
# 14        1015   Male   22            2          68     58         CS
# 16        1017   Male   21            4          82     75         CS
# 18        1019   Male   19            3          71     60         CS

# %%
df[cs]["Marks"].mean()
# Out:
# np.float64(63.6)

# %%
IT = (df["Department"] == "IT")
df[IT]
# Out:
#     Student_ID  Gender  Age  Study_Hours  Attendance  Marks Department
# 1         1002  Female   20            5          92     84         IT
# 3         1004  Female   21            6          95     91         IT
# 5         1006  Female   19            7          97     95         IT
# 7         1008  Female   20            5          89     82         IT
# 9         1010  Female   19            8          98     97         IT
# 11        1012  Female   21            6          91     88         IT
# 13        1014  Female   20            5          88     79         IT
# 15        1016  Female   19            7          96     93         IT
# 17        1018  Female   20            6          94     90         IT
# 19        1020  Female   22            5          86     81         IT

# %%
df[IT]["Marks"].mean()
# Out:
# np.float64(88.0)

# %%
df["Gender"].value_counts()
# Out:
# Gender
# Male      10
# Female    10
# Name: count, dtype: int64

# %%
Male = df["Gender"] == "Male"
df[Male]["Marks"].mean()
# Out:
# np.float64(63.6)

# %%
Female = df["Gender"] == "Female"
df[Female]["Marks"].mean()
# Out:
# np.float64(88.0)

# %%
df["Study_Hours"].max()
# Out:
# 8

# %%
df["Study_Hours"].min()
# Out:
# 2

# %%
df["Study_Hours"].mean()
# Out:
# np.float64(4.5)

# %%
df["Attendance"].max()
# Out:
# 98

# %%
df["Attendance"].min()
# Out:
# 61

# %%
df["Attendance"].mean()
# Out:
# np.float64(83.2)

# %%
Top_Performers = df["Marks"]>=80

# %%
Top_Performers
# Out:
# 0     False
# 1      True
# 2     False
# 3      True
# 4     False
# 5      True
# 6     False
# 7      True
# 8     False
# 9      True
# 10    False
# 11     True
# 12    False
# 13    False
# 14    False
# 15     True
# 16    False
# 17     True
# 18    False
# 19     True
# Name: Marks, dtype: bool

# %%
Top_Performers.sum()
# Out:
# np.int64(9)

# %%
Attendance = df["Attendance"]>=90
Attendance.sum()
# Out:
# np.int64(7)

# %%
High_Attendance__Marks = (df["Attendance"]>=90) & (df["Marks"]>=80)
High_Attendance__Marks.sum()
# Out:
# np.int64(7)

# %%
df[df["Attendance"]>=90]["Marks"].mean()
# Out:
# np.float64(91.14285714285714)

# %%
df[df["Attendance"]>=90]["Marks"].max()
# Out:
# 97

# %%
df[df["Study_Hours"]>=5]["Marks"].mean()
# Out:
# np.float64(88.0)

# %%
df[df["Study_Hours"]>=5]["Marks"].min()
# Out:
# 79

# %%
df[df["Study_Hours"]>=5]["Marks"].max()
# Out:
# 97

# %%
df[df["Gender"] == "Female"]["Marks"].min()
# Out:
# 79

# %%
df[df["Gender"] == "Female"]["Marks"].max()
# Out:
# 97

# %%
df[df["Gender"] == "Male"]["Marks"].mean()
# Out:
# np.float64(63.6)

# %%
df[df["Gender"] == "Male"]["Marks"].max()
# Out:
# 75

# %%
df[df["Department"] == "IT"]["Marks"].min()
# Out:
# 79

# %%
df[df["Department"] == "CS"]["Attendance"].max()
# Out:
# 84

# %%
df[df["Department"] == "CS"]["Attendance"].mean()
# Out:
# np.float64(73.8)
